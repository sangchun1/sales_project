# %%
# 필요한 모듈 불러오기
import pandas as pd
import numpy as np

# %%
# 데이터 파일 불러오기
df = pd.read_csv("./KGU_3rd_ORIGIN_KGUAREADOITEM_20210701000000.csv")

# %%
df
# Out:
#         ﻿2021-07-01  00  목요일   충청남도  천안시 동남구  돈까스/일식
# 0        2021-07-01   0  목요일   충청남도  천안시 동남구   족발/보쌈
# 1        2021-07-01   0  목요일    경기도     동두천시  돈까스/일식
# 2        2021-07-01   0  목요일    경기도     동두천시  돈까스/일식
# 3        2021-07-01   0  목요일   경상북도      영천시  돈까스/일식
# 4        2021-07-01   0  목요일   경상북도      영천시  돈까스/일식
# ...             ...  ..  ...    ...      ...     ...
# 4271690  2021-12-31  23  금요일   경상남도      진주시      분식
# 4271691  2021-12-31  23  금요일  부산광역시      강서구      치킨
# 4271692  2021-12-31  23  금요일  부산광역시      강서구      치킨
# 4271693  2021-12-31  23  금요일  부산광역시      강서구      치킨
# 4271694  2021-12-31  23  금요일    경기도      군포시  카페/디저트
#
# [4271695 rows x 6 columns]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# ﻿2021-07-01    0
# 00             0
# 목요일            0
# 충청남도           0
# 천안시 동남구        0
# 돈까스/일식         0
# dtype: int64

# %%
# 컬럼명 변경
df.rename(columns={'﻿2021-07-01':'년월일'}, inplace=True)
df.rename(columns={'00':'주문시간'}, inplace=True)
df.rename(columns={'충청남도':'시도'},inplace=True)
df.rename(columns={'목요일':'요일'},inplace=True)
df.rename(columns={'천안시 동남구':'시군구'},inplace=True)
df.rename(columns={'돈까스/일식':'음식분류'},inplace=True)

# %%
df
# Out:
#                 년월일  주문시간   요일     시도      시군구    음식분류
# 0        2021-07-01     0  목요일   충청남도  천안시 동남구   족발/보쌈
# 1        2021-07-01     0  목요일    경기도     동두천시  돈까스/일식
# 2        2021-07-01     0  목요일    경기도     동두천시  돈까스/일식
# 3        2021-07-01     0  목요일   경상북도      영천시  돈까스/일식
# 4        2021-07-01     0  목요일   경상북도      영천시  돈까스/일식
# ...             ...   ...  ...    ...      ...     ...
# 4271690  2021-12-31    23  금요일   경상남도      진주시      분식
# 4271691  2021-12-31    23  금요일  부산광역시      강서구      치킨
# 4271692  2021-12-31    23  금요일  부산광역시      강서구      치킨
# 4271693  2021-12-31    23  금요일  부산광역시      강서구      치킨
# 4271694  2021-12-31    23  금요일    경기도      군포시  카페/디저트
#
# [4271695 rows x 6 columns]

# %%
# 시도에서 서울특별시에 해당하는 데이터만 추출
df_seoul = df.loc[df['시도'].isin(['서울특별시'])]

# %%
# 인덱스 기준을 년월일로 수정
df_seoul.set_index('년월일', inplace=True)

# %%
df_seoul
# Out:
#             주문시간   요일     시도  시군구    음식분류
# 년월일
# 2021-07-01     0  목요일  서울특별시  동작구      치킨
# 2021-07-01     0  목요일  서울특별시  금천구  돈까스/일식
# 2021-07-01     0  목요일  서울특별시  금천구  돈까스/일식
# 2021-07-01     0  목요일  서울특별시  금천구  돈까스/일식
# 2021-07-01     0  목요일  서울특별시  금천구      치킨
# ...          ...  ...    ...  ...     ...
# 2021-12-31    23  금요일  서울특별시  구로구      야식
# 2021-12-31    23  금요일  서울특별시  구로구      야식
# 2021-12-31    23  금요일  서울특별시  강서구      한식
# 2021-12-31    23  금요일  서울특별시  강서구      야식
# 2021-12-31    23  금요일  서울특별시  금천구  돈까스/일식
#
# [366165 rows x 5 columns]

# %%
df_seoul = df_seoul[df_seoul.음식분류 != '심부름']
df_seoul = df_seoul[df_seoul.음식분류 != '야식']
df_seoul = df_seoul[df_seoul.음식분류 != '배달전문업체']

# %%
df_seoul
# Out:
#             주문시간   요일     시도   시군구    음식분류
# 년월일
# 2021-07-01     0  목요일  서울특별시   동작구      치킨
# 2021-07-01     0  목요일  서울특별시   금천구  돈까스/일식
# 2021-07-01     0  목요일  서울특별시   금천구  돈까스/일식
# 2021-07-01     0  목요일  서울특별시   금천구  돈까스/일식
# 2021-07-01     0  목요일  서울특별시   금천구      치킨
# ...          ...  ...    ...   ...     ...
# 2021-12-31    23  금요일  서울특별시  영등포구      찜탕
# 2021-12-31    23  금요일  서울특별시  영등포구      찜탕
# 2021-12-31    23  금요일  서울특별시   구로구  돈까스/일식
# 2021-12-31    23  금요일  서울특별시   강서구      한식
# 2021-12-31    23  금요일  서울특별시   금천구  돈까스/일식
#
# [354244 rows x 5 columns]

# %%
df_seoul.to_csv("202107~202112지역별요일별배달품목.csv")
