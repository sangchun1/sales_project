# %%
import pandas as pd

# %%
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
df1 = pd.read_csv("./csv/order_food.csv")
df2 = pd.read_csv("./csv/seoul_population.csv")

# %%
df3 = pd.read_csv("./csv/order_trend.csv")
df4 = pd.read_csv("./csv/time_int_order.csv")
df5 = pd.read_csv("./csv/Preprocessing_Online_consumption_data.csv")
df6 = pd.read_csv("./csv/Preprocessing_Seoul_store_data.csv")

# %%
df1
# Out:
#         Unnamed: 0        date  time_int days    gu    food  order_cnt
# 0                0  2019-07-31         0  수요일  영등포구      치킨         15
# 1                1  2019-07-31         0  수요일   은평구   족발/보쌈          7
# 2                2  2019-07-31         0  수요일   구로구   패스트푸드         16
# 3                3  2019-07-31         0  수요일   금천구      한식          2
# 4                4  2019-07-31         0  수요일  영등포구      피자         15
# ...            ...         ...       ...  ...   ...     ...        ...
# 452769      452769  2021-12-31        23  금요일   금천구  카페/디저트         29
# 452770      452770  2021-12-31        23  금요일   은평구      치킨          1
# 452771      452771  2021-12-31        23  금요일   금천구      한식         29
# 452772      452772  2021-12-31        23  금요일   구로구  돈까스/일식         10
# 452773      452773  2021-12-31        23  금요일   강서구      한식          7
#
# [452774 rows x 7 columns]

# %%
df2
# Out:
#      Unnamed: 0   gu age_group  population    male  female
# 0             0  종로구    20대 미만       18355    9182    9173
# 1             1  종로구       20대       28087   13055   15032
# 2             2  종로구       30대       10782    5416    5366
# 3             3  종로구       40대        9502    4744    4758
# 4             4  종로구       50대        9816    4756    5060
# ..          ...  ...       ...         ...     ...     ...
# 145         145  강동구       20대       58184   28296   29888
# 146         146  강동구       30대       33898   16735   17163
# 147         147  강동구       40대       35993   17912   18081
# 148         148  강동구       50대       37290   18631   18659
# 149         149  강동구    60대 이상      214654  102042  112612
#
# [150 rows x 6 columns]

# %%
df1.drop(['Unnamed: 0'],axis= 1 , inplace=True)
df2.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
df5
# Out:
#       거래시간       카드매출금액   카드매출건수  건당매출금액
# 0  00시-03시   4884198000   223313   43722
# 1  03시-06시    920051000    42838   42883
# 2  06시-09시    756129000    38516   39310
# 3  09시-12시  14261674000   723857   39262
# 4  09시-15시  26025059000  1309839   39538
# 5  15시-18시  30620190000  1422802   42578
# 6  18시-21시  62389599000  2809301   44007
# 7  21시-24시  24698759000  1140673   43205

# %%
df3.drop(['Unnamed: 0'],axis= 1 , inplace=True)
df4.drop(['Unnamed: 0'], axis=1,inplace=True)
df6.drop(['Unnamed: 0'], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df3.drop(['Unnamed: 0'],axis= 1 , inplace=True)
#       2 df4.drop(['Unnamed: 0'], axis=1,inplace=True)
#       3 df6.drop(['Unnamed: 0'], axis=1,inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df3
# Out:
#        date sex age_group   order_amt  order_cnt
# 0    201901   남       20대   100676078       4702
# 1    201901   남       30대   340178597      14885
# 2    201901   남       40대   200274889       8715
# 3    201901   남       50대    66215884       2991
# 4    201901   남     60대이상    14937982        645
# ..      ...  ..       ...         ...        ...
# 475  202212   여       20대  1236962400      49210
# 476  202212   여       30대  3818296810     140616
# 477  202212   여       40대  5962448786     213270
# 478  202212   여       50대  2721434095     100281
# 479  202212   여     60대이상   616935270      21786
#
# [480 rows x 5 columns]

# %%
df4
# Out:
#               date  time_int   food   gu  avg_order_amt  order_cnt
# 0       2019-05-19        14     치킨   중구           2750          1
# 1       2019-05-21        16     한식  도봉구            100          1
# 2       2019-05-24        12     치킨  도봉구              0          1
# 3       2019-05-27        23     치킨   중구           2750          1
# 4       2019-05-29        16     치킨  도봉구              0          1
# ...            ...       ...    ...  ...            ...        ...
# 703649  2021-07-31        23  패스트푸드  서초구          18000          1
# 703650  2021-07-31        23  패스트푸드  양천구          16900          1
# 703651  2021-07-31        23     한식  관악구          17100          1
# 703652  2021-07-31        23     한식  금천구          21960          1
# 703653  2021-07-31        23     한식  도봉구           5850          1
#
# [703654 rows x 6 columns]

# %%
df5
# Out:
#       거래시간       카드매출금액   카드매출건수  건당매출금액
# 0  00시-03시   4884198000   223313   43722
# 1  03시-06시    920051000    42838   42883
# 2  06시-09시    756129000    38516   39310
# 3  09시-12시  14261674000   723857   39262
# 4  09시-15시  26025059000  1309839   39538
# 5  15시-18시  30620190000  1422802   42578
# 6  18시-21시  62389599000  2809301   44007
# 7  21시-24시  24698759000  1140673   43205

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df= flights.pivot('month','year','passengers')
df
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11064\711985867.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df= flights.pivot('month','year','passengers')
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# ...

# %%
ax=sns.heatmap(df, cmap='Blues')

# %%
sns.set()
sns.set_style('whitegrid')
sns.set_color_codes()

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.relplot(x="order_cnt", y="time_int",
            data=df1)

# %%
sns.pairplot(df1,hue='food')

# %%
sns.pairplot(df2,hue="gu")

# %%
sns.pairplot(df3, hue='age_group')
# Out:
# C:\Users\tjoeun\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.

# %%
sns.pairplot(df4,hue='time_int')

# %%
sns.pairplot(df5, hue="거래시간")

# %%
import plotnine
from plotnine import *

# %%
import pyecharts

# %%
pivot = df1.pivot_table(index='food', columns='time_int', values='order_cnt')
pivot
# Out:
# time_int         0          1          2          3          4          5   \
# food
# 도시락       25.000000  15.400000  16.500000  15.500000  13.000000  14.250000
# 돈까스/일식     8.323113   5.541812   6.913043   5.478632   4.839744  10.148148
# 분식        17.453917   8.806202   6.301887   4.030303   3.000000   3.666667
# 아시안/양식    19.777778  19.222222  24.782609  19.250000  14.785714  13.090909
# 야식        13.541007   8.911376   5.036735   3.888889   6.250000        NaN
# 족발/보쌈     14.782710   9.336986  11.306667  16.875000  18.066667  13.500000
# 중식        20.700441  12.507143   6.100000   6.272727   5.666667  13.000000
# 찜탕        15.045016   7.702929   8.703704  10.266667  10.315789  14.611111
# 치킨        12.596146   7.990125   5.956800   6.853261   7.213115   5.375000
# 카페/디저트    20.959732  13.567708  11.500000   7.247059   8.500000  14.100000
# 패스트푸드     13.478648   7.397412   6.371765   5.087470   5.025701   3.900000
# ...

# %%
sns.heatmap(pivot) #cmap으로 전체적인 컬러 조정 가능
plt.show()

# %%
df1.corr()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11064\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#            time_int  order_cnt
# time_int   1.000000   0.235695
# order_cnt  0.235695   1.000000

# %%
sns.heatmap(df1.corr(), annot=True, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11064\205541750.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
sns.violinplot(x="days", y="order_cnt", data=df1)
plt.show()

# %%
df1
# Out:
#               date  time_int days    gu    food  order_cnt
# 0       2019-07-31         0  수요일  영등포구      치킨         15
# 1       2019-07-31         0  수요일   은평구   족발/보쌈          7
# 2       2019-07-31         0  수요일   구로구   패스트푸드         16
# 3       2019-07-31         0  수요일   금천구      한식          2
# 4       2019-07-31         0  수요일  영등포구      피자         15
# ...            ...       ...  ...   ...     ...        ...
# 452769  2021-12-31        23  금요일   금천구  카페/디저트         29
# 452770  2021-12-31        23  금요일   은평구      치킨          1
# 452771  2021-12-31        23  금요일   금천구      한식         29
# 452772  2021-12-31        23  금요일   구로구  돈까스/일식         10
# 452773  2021-12-31        23  금요일   강서구      한식          7
#
# [452774 rows x 6 columns]

# %%
sns.heatmap(df2.corr(), annot=True, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11064\945089394.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
sns.heatmap(df3.corr(), annot=True, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11064\3269477320.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
sns.violinplot(x="age_group", y="population", data=df2)
plt.show()

# %%
df2
# Out:
#       gu age_group  population    male  female
# 0    종로구    20대 미만       18355    9182    9173
# 1    종로구       20대       28087   13055   15032
# 2    종로구       30대       10782    5416    5366
# 3    종로구       40대        9502    4744    4758
# 4    종로구       50대        9816    4756    5060
# ..   ...       ...         ...     ...     ...
# 145  강동구       20대       58184   28296   29888
# 146  강동구       30대       33898   16735   17163
# 147  강동구       40대       35993   17912   18081
# 148  강동구       50대       37290   18631   18659
# 149  강동구    60대 이상      214654  102042  112612
#
# [150 rows x 5 columns]

# %%
pivot2 = df2.pivot_table(index='age_group', columns='gu', values='population')
pivot
# Out:
# time_int         0          1          2          3          4          5   \
# food
# 도시락       25.000000  15.400000  16.500000  15.500000  13.000000  14.250000
# 돈까스/일식     8.323113   5.541812   6.913043   5.478632   4.839744  10.148148
# 분식        17.453917   8.806202   6.301887   4.030303   3.000000   3.666667
# 아시안/양식    19.777778  19.222222  24.782609  19.250000  14.785714  13.090909
# 야식        13.541007   8.911376   5.036735   3.888889   6.250000        NaN
# 족발/보쌈     14.782710   9.336986  11.306667  16.875000  18.066667  13.500000
# 중식        20.700441  12.507143   6.100000   6.272727   5.666667  13.000000
# 찜탕        15.045016   7.702929   8.703704  10.266667  10.315789  14.611111
# 치킨        12.596146   7.990125   5.956800   6.853261   7.213115   5.375000
# 카페/디저트    20.959732  13.567708  11.500000   7.247059   8.500000  14.100000
# 패스트푸드     13.478648   7.397412   6.371765   5.087470   5.025701   3.900000
# ...

# %%
sns.heatmap(pivot2) #cmap으로 전체적인 컬러 조정 가능
plt.show()
